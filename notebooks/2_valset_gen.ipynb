# %% [markdown]
# #### validation dataset generation

# %%
import torch
import numpy as np
from glob import glob
import rasterio as rio
from pyrsimg import img2patch
from pyrsimg import imsShow, imgShow
from torchvision.transforms import v2

# %%
dir_val_scene = 'data/dset/dset_split/val/scene' 
dir_val_truth = 'data/dset/dset_split/val/truth' 
dir_val_patch = 'data/dset/dset_split/val_patch' 
patch_size = 512  ## base patch size
# ## valset
paths_val_scene = sorted(glob(dir_val_scene+'/*.tif'))
paths_val_truth = sorted(glob(dir_val_truth+'/*.tif'))
paths_valset = list(zip(paths_val_scene, paths_val_truth))
print(len(paths_valset))   
paths_valset[4]
# Out:
# 43
# ('data/dset/dset_split/val/scene/S2A_L2A_20190508_N0212_R078_S3.tif',
#  'data/dset/dset_split/val/truth/S2A_L2A_20190508_N0212_R078_S3_truth.tif')

# %%
## generate validation patches (include patch,dem,truth)
dset_patch_list = []
dset_start_list = []
dset_list = []       ## [patches, higher_patches]
for path_scene,  path_truth in paths_valset:
    print(path_scene)
    scene_val_arr = rio.open(path_scene).read()   ## (C, H, W)
    truth_val_arr = rio.open(path_truth).read(1)
    size_global = scene_val_arr.shape[1:]
    ## image to patches
    scene_truth_arr = np.concatenate([scene_val_arr, 
                                        truth_val_arr[np.newaxis, ...]], 
                                        axis=0)
    scene_truth_arr_ = torch.from_numpy(scene_truth_arr).to(dtype=torch.float16)
    img2patches = img2patch(img = scene_truth_arr_.numpy().transpose(1,2,0), 
                            patch_size = patch_size, 
                            edge_overlay = 50,  ## 50 for patch_512, 100 for patch_1024
                            )  
    patch_truth_list = img2patches.toPatch()  
    patch_lat_list = [scene_val_arr]*len(patch_truth_list)
    print(len(patch_truth_list))
    dset_list.extend(patch_truth_list)
    # break
print('num of patches:', len(dset_list))
# Out:
# data/dset/dset_split/val/scene/S2A_L2A_20190125_N0211_R034_S1.tif
# 4
# data/dset/dset_split/val/scene/S2A_L2A_20190206_N0211_R067_S3.tif
# 9
# data/dset/dset_split/val/scene/S2A_L2A_20190318_N0211_R061_S2.tif
# 4
# data/dset/dset_split/val/scene/S2A_L2A_20190429_N0211_R096_S1.tif
# 6
# data/dset/dset_split/val/scene/S2A_L2A_20190508_N0212_R078_S3.tif
# 4
# data/dset/dset_split/val/scene/S2A_L2A_20190716_N0213_R063_S2.tif
# 6
# data/dset/dset_split/val/scene/S2A_L2A_20190725_N0213_R054_S1.tif
# 4
# data/dset/dset_split/val/scene/S2A_L2A_20190811_N0213_R013_S2.tif
# 9
# data/dset/dset_split/val/scene/S2A_L2A_20190817_N0213_R089_S4.tif
# 4
# data/dset/dset_split/val/scene/S2B_L2A_20181226_N0211_R102_S2.tif
# 9
# data/dset/dset_split/val/scene/S2B_L2A_20190303_N0211_R065_S1.tif
# 9
# data/dset/dset_split/val/scene/S2B_L2A_20190430_N0211_R035_S3.tif
# 9
# data/dset/dset_split/val/scene/S2B_L2A_20190607_N0212_R012_S2.tif
# 6
# data/dset/dset_split/val/scene/S2B_L2A_20190620_N0212_R053_S1.tif
# 9
# data/dset/dset_split/val/scene/S2B_L2A_20190801_N0213_R084_S3.tif
# 6
# data/dset/dset_split/val/scene/S2B_L2A_20190811_N0213_R079_S2.tif
# 6
# data/dset/dset_split/val/scene/S2B_L2A_20190831_N0213_R082_S1.tif
# 6
# data/dset/dset_split/val/scene/S2B_L2A_20190904_N0213_R132_S3.tif
# 9
# data/dset/dset_split/val/scene/S2B_L2A_20191015_N0213_R007_S2.tif
# 4
# data/dset/dset_split/val/scene/l5_scene_01.tif
# 9
# data/dset/dset_split/val/scene/l5_scene_06.tif
# 9
# data/dset/dset_split/val/scene/l5_scene_11.tif
# 9
# data/dset/dset_split/val/scene/l5_scene_16.tif
# 9
# data/dset/dset_split/val/scene/l5_scene_21.tif
# 9
# data/dset/dset_split/val/scene/l5_scene_26.tif
# 9
# data/dset/dset_split/val/scene/l7_scene_01.tif
# 9
# data/dset/dset_split/val/scene/l7_scene_06.tif
# 9
# data/dset/dset_split/val/scene/l7_scene_11.tif
# 9
# data/dset/dset_split/val/scene/l7_scene_16.tif
# 9
# data/dset/dset_split/val/scene/l7_scene_21.tif
# 9
# data/dset/dset_split/val/scene/l7_scene_26.tif
# 9
# data/dset/dset_split/val/scene/l8_scene_01.tif
# 16
# data/dset/dset_split/val/scene/l8_scene_06.tif
# 9
# data/dset/dset_split/val/scene/l8_scene_11.tif
# 12
# data/dset/dset_split/val/scene/l8_scene_16.tif
# 9
# data/dset/dset_split/val/scene/l8_scene_21.tif
# 9
# data/dset/dset_split/val/scene/l8_scene_26.tif
# 9
# data/dset/dset_split/val/scene/l9_scene_01.tif
# 16
# data/dset/dset_split/val/scene/l9_scene_06.tif
# 20
# data/dset/dset_split/val/scene/l9_scene_11.tif
# 16
# data/dset/dset_split/val/scene/l9_scene_16.tif
# 16
# data/dset/dset_split/val/scene/l9_scene_21.tif
# 16
# data/dset/dset_split/val/scene/l9_scene_26.tif
# 20
# num of patches: 399

# %%
'''----  save multiscale patch data  ----'''
dir_valset = f'data/dset/dset_split/val_patch/patch_{patch_size}'
for id_patch, patch_ptruth in enumerate(dset_list):
    print(id_patch)
    patch_ptruth_ = torch.from_numpy(patch_ptruth).permute(2,0,1)  ## (C, H, W)
    ## save as float16 to save space
    patch_ptruth_ = patch_ptruth_.to(dtype=torch.float16)
    path_save = dir_valset+f'/patch_ptruth_' + str(id_patch).rjust(4,'0')+'.pth'
    print(path_save)
    torch.save((patch_ptruth_), path_save)
    # break
# Out:
# 0
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0000.pth
# 1
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0001.pth
# 2
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0002.pth
# 3
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0003.pth
# 4
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0004.pth
# 5
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0005.pth
# 6
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0006.pth
# 7
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0007.pth
# 8
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0008.pth
# 9
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0009.pth
# 10
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0010.pth
# 11
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0011.pth
# 12
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0012.pth
# 13
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0013.pth
# 14
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0014.pth
# 15
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0015.pth
# 16
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0016.pth
# 17
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0017.pth
# 18
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0018.pth
# 19
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0019.pth
# 20
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0020.pth
# 21
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0021.pth
# 22
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0022.pth
# 23
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0023.pth
# 24
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0024.pth
# 25
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0025.pth
# 26
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0026.pth
# 27
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0027.pth
# 28
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0028.pth
# 29
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0029.pth
# 30
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0030.pth
# 31
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0031.pth
# 32
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0032.pth
# 33
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0033.pth
# 34
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0034.pth
# 35
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0035.pth
# 36
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0036.pth
# 37
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0037.pth
# 38
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0038.pth
# 39
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0039.pth
# 40
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0040.pth
# 41
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0041.pth
# 42
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0042.pth
# 43
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0043.pth
# 44
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0044.pth
# 45
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0045.pth
# 46
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0046.pth
# 47
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0047.pth
# 48
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0048.pth
# 49
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0049.pth
# 50
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0050.pth
# 51
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0051.pth
# 52
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0052.pth
# 53
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0053.pth
# 54
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0054.pth
# 55
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0055.pth
# 56
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0056.pth
# 57
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0057.pth
# 58
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0058.pth
# 59
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0059.pth
# 60
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0060.pth
# 61
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0061.pth
# 62
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0062.pth
# 63
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0063.pth
# 64
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0064.pth
# 65
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0065.pth
# 66
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0066.pth
# 67
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0067.pth
# 68
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0068.pth
# 69
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0069.pth
# 70
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0070.pth
# 71
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0071.pth
# 72
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0072.pth
# 73
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0073.pth
# 74
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0074.pth
# 75
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0075.pth
# 76
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0076.pth
# 77
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0077.pth
# 78
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0078.pth
# 79
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0079.pth
# 80
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0080.pth
# 81
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0081.pth
# 82
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0082.pth
# 83
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0083.pth
# 84
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0084.pth
# 85
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0085.pth
# 86
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0086.pth
# 87
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0087.pth
# 88
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0088.pth
# 89
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0089.pth
# 90
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0090.pth
# 91
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0091.pth
# 92
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0092.pth
# 93
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0093.pth
# 94
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0094.pth
# 95
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0095.pth
# 96
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0096.pth
# 97
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0097.pth
# 98
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0098.pth
# 99
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0099.pth
# 100
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0100.pth
# 101
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0101.pth
# 102
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0102.pth
# 103
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0103.pth
# 104
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0104.pth
# 105
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0105.pth
# 106
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0106.pth
# 107
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0107.pth
# 108
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0108.pth
# 109
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0109.pth
# 110
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0110.pth
# 111
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0111.pth
# 112
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0112.pth
# 113
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0113.pth
# 114
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0114.pth
# 115
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0115.pth
# 116
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0116.pth
# 117
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0117.pth
# 118
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0118.pth
# 119
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0119.pth
# 120
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0120.pth
# 121
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0121.pth
# 122
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0122.pth
# 123
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0123.pth
# 124
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0124.pth
# 125
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0125.pth
# 126
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0126.pth
# 127
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0127.pth
# 128
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0128.pth
# 129
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0129.pth
# 130
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0130.pth
# 131
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0131.pth
# 132
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0132.pth
# 133
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0133.pth
# 134
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0134.pth
# 135
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0135.pth
# 136
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0136.pth
# 137
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0137.pth
# 138
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0138.pth
# 139
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0139.pth
# 140
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0140.pth
# 141
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0141.pth
# 142
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0142.pth
# 143
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0143.pth
# 144
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0144.pth
# 145
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0145.pth
# 146
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0146.pth
# 147
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0147.pth
# 148
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0148.pth
# 149
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0149.pth
# 150
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0150.pth
# 151
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0151.pth
# 152
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0152.pth
# 153
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0153.pth
# 154
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0154.pth
# 155
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0155.pth
# 156
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0156.pth
# 157
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0157.pth
# 158
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0158.pth
# 159
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0159.pth
# 160
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0160.pth
# 161
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0161.pth
# 162
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0162.pth
# 163
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0163.pth
# 164
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0164.pth
# 165
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0165.pth
# 166
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0166.pth
# 167
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0167.pth
# 168
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0168.pth
# 169
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0169.pth
# 170
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0170.pth
# 171
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0171.pth
# 172
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0172.pth
# 173
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0173.pth
# 174
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0174.pth
# 175
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0175.pth
# 176
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0176.pth
# 177
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0177.pth
# 178
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0178.pth
# 179
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0179.pth
# 180
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0180.pth
# 181
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0181.pth
# 182
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0182.pth
# 183
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0183.pth
# 184
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0184.pth
# 185
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0185.pth
# 186
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0186.pth
# 187
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0187.pth
# 188
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0188.pth
# 189
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0189.pth
# 190
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0190.pth
# 191
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0191.pth
# 192
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0192.pth
# 193
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0193.pth
# 194
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0194.pth
# 195
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0195.pth
# 196
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0196.pth
# 197
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0197.pth
# 198
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0198.pth
# 199
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0199.pth
# 200
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0200.pth
# 201
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0201.pth
# 202
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0202.pth
# 203
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0203.pth
# 204
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0204.pth
# 205
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0205.pth
# 206
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0206.pth
# 207
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0207.pth
# 208
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0208.pth
# 209
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0209.pth
# 210
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0210.pth
# 211
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0211.pth
# 212
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0212.pth
# 213
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0213.pth
# 214
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0214.pth
# 215
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0215.pth
# 216
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0216.pth
# 217
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0217.pth
# 218
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0218.pth
# 219
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0219.pth
# 220
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0220.pth
# 221
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0221.pth
# 222
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0222.pth
# 223
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0223.pth
# 224
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0224.pth
# 225
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0225.pth
# 226
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0226.pth
# 227
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0227.pth
# 228
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0228.pth
# 229
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0229.pth
# 230
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0230.pth
# 231
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0231.pth
# 232
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0232.pth
# 233
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0233.pth
# 234
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0234.pth
# 235
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0235.pth
# 236
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0236.pth
# 237
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0237.pth
# 238
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0238.pth
# 239
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0239.pth
# 240
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0240.pth
# 241
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0241.pth
# 242
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0242.pth
# 243
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0243.pth
# 244
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0244.pth
# 245
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0245.pth
# 246
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0246.pth
# 247
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0247.pth
# 248
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0248.pth
# 249
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0249.pth
# 250
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0250.pth
# 251
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0251.pth
# 252
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0252.pth
# 253
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0253.pth
# 254
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0254.pth
# 255
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0255.pth
# 256
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0256.pth
# 257
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0257.pth
# 258
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0258.pth
# 259
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0259.pth
# 260
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0260.pth
# 261
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0261.pth
# 262
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0262.pth
# 263
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0263.pth
# 264
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0264.pth
# 265
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0265.pth
# 266
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0266.pth
# 267
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0267.pth
# 268
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0268.pth
# 269
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0269.pth
# 270
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0270.pth
# 271
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0271.pth
# 272
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0272.pth
# 273
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0273.pth
# 274
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0274.pth
# 275
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0275.pth
# 276
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0276.pth
# 277
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0277.pth
# 278
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0278.pth
# 279
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0279.pth
# 280
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0280.pth
# 281
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0281.pth
# 282
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0282.pth
# 283
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0283.pth
# 284
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0284.pth
# 285
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0285.pth
# 286
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0286.pth
# 287
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0287.pth
# 288
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0288.pth
# 289
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0289.pth
# 290
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0290.pth
# 291
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0291.pth
# 292
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0292.pth
# 293
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0293.pth
# 294
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0294.pth
# 295
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0295.pth
# 296
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0296.pth
# 297
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0297.pth
# 298
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0298.pth
# 299
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0299.pth
# 300
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0300.pth
# 301
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0301.pth
# 302
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0302.pth
# 303
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0303.pth
# 304
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0304.pth
# 305
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0305.pth
# 306
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0306.pth
# 307
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0307.pth
# 308
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0308.pth
# 309
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0309.pth
# 310
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0310.pth
# 311
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0311.pth
# 312
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0312.pth
# 313
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0313.pth
# 314
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0314.pth
# 315
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0315.pth
# 316
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0316.pth
# 317
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0317.pth
# 318
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0318.pth
# 319
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0319.pth
# 320
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0320.pth
# 321
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0321.pth
# 322
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0322.pth
# 323
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0323.pth
# 324
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0324.pth
# 325
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0325.pth
# 326
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0326.pth
# 327
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0327.pth
# 328
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0328.pth
# 329
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0329.pth
# 330
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0330.pth
# 331
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0331.pth
# 332
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0332.pth
# 333
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0333.pth
# 334
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0334.pth
# 335
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0335.pth
# 336
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0336.pth
# 337
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0337.pth
# 338
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0338.pth
# 339
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0339.pth
# 340
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0340.pth
# 341
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0341.pth
# 342
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0342.pth
# 343
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0343.pth
# 344
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0344.pth
# 345
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0345.pth
# 346
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0346.pth
# 347
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0347.pth
# 348
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0348.pth
# 349
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0349.pth
# 350
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0350.pth
# 351
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0351.pth
# 352
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0352.pth
# 353
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0353.pth
# 354
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0354.pth
# 355
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0355.pth
# 356
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0356.pth
# 357
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0357.pth
# 358
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0358.pth
# 359
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0359.pth
# 360
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0360.pth
# 361
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0361.pth
# 362
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0362.pth
# 363
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0363.pth
# 364
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0364.pth
# 365
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0365.pth
# 366
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0366.pth
# 367
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0367.pth
# 368
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0368.pth
# 369
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0369.pth
# 370
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0370.pth
# 371
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0371.pth
# 372
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0372.pth
# 373
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0373.pth
# 374
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0374.pth
# 375
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0375.pth
# 376
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0376.pth
# 377
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0377.pth
# 378
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0378.pth
# 379
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0379.pth
# 380
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0380.pth
# 381
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0381.pth
# 382
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0382.pth
# 383
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0383.pth
# 384
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0384.pth
# 385
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0385.pth
# 386
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0386.pth
# 387
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0387.pth
# 388
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0388.pth
# 389
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0389.pth
# 390
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0390.pth
# 391
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0391.pth
# 392
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0392.pth
# 393
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0393.pth
# 394
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0394.pth
# 395
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0395.pth
# 396
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0396.pth
# 397
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0397.pth
# 398
# data/dset/dset_split/val_patch/patch_512/patch_ptruth_0398.pth

# %% [markdown]
# ### load data and check

# %%
## load data
paths_valset = sorted(glob('data/dset/dset_split/val_patch/patch_512/*'))
valset_list = [torch.load(path, weights_only=False) for path in paths_valset]
print(len(valset_list))
# Out:
# 399

# %%
# id = np.random.randint(0, len(valset_list))
id = 131
patch_ptruth = valset_list[id]
patch, ptruth = patch_ptruth[0:6, :, :], patch_ptruth[6:7, :, :]
imgs_name = ['patch', 'ptruth']  
clip_list = [2, 0]  
col_bands_list = [(3,2,1), (0,0,0)]
imsShow(img_list=[patch.numpy().transpose(1,2,0), 
                  ptruth.numpy().transpose(1,2,0)], 
            img_name_list=imgs_name,    
            clip_list=clip_list,  
            color_bands_list=col_bands_list,
            figsize=(7, 3));
