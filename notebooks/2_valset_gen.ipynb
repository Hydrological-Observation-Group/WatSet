# %% [markdown]
# #### validation dataset generation

# %%
import torch
import numpy as np
from glob import glob
import rasterio as rio
from notebooks import config
from pyrsimg import img2patch
from pyrsimg import imsShow, imgShow
from torchvision.transforms import v2

# %%
patch_size = 512  ## base patch size
# ## valset
paths_valset = list(zip(config.paths_scene_val, config.paths_truth_val))
print(len(paths_valset))
paths_valset[4]
# Out:
# 43
# ('data/dset/scene/scene_nor/l5/l5_scene_21.tif',
#  'data/dset/truth/truth_tif/l5/l5_scene_21_truth_final.tif')

# %%
## generate validation patches (include patch,dem,truth)
dset_patch_list = []
dset_start_list = []
dset_list = []       ## [patches, higher_patches]
for path_scene,  path_truth in paths_valset:
    print(path_scene)
    scene_val_arr = rio.open(path_scene).read()   ## (C, H, W)
    truth_val_arr = rio.open(path_truth).read(1)
    size_global = scene_val_arr.shape[1:]
    ## image to patches
    scene_truth_arr = np.concatenate([scene_val_arr, 
                                        truth_val_arr[np.newaxis, ...]], 
                                        axis=0)
    scene_truth_arr_ = torch.from_numpy(scene_truth_arr).to(dtype=torch.float16)
    img2patches = img2patch(img = scene_truth_arr_.numpy().transpose(1,2,0), 
                            patch_size = patch_size, 
                            edge_overlay = 40,  ## 40,100 for patch_512, patch_1024
                            drop_last=True)
    patch_truth_list = img2patches.toPatch()
    patch_lat_list = [scene_val_arr]*len(patch_truth_list)
    print(len(patch_truth_list))
    dset_list.extend(patch_truth_list)
    # break
print('num of patches:', len(dset_list))
# Out:
# data/dset/scene/scene_nor/l5/l5_scene_01.tif
# 4
# data/dset/scene/scene_nor/l5/l5_scene_06.tif
# 4
# data/dset/scene/scene_nor/l5/l5_scene_11.tif
# 4
# data/dset/scene/scene_nor/l5/l5_scene_16.tif
# 4
# data/dset/scene/scene_nor/l5/l5_scene_21.tif
# 4
# data/dset/scene/scene_nor/l5/l5_scene_26.tif
# 6
# data/dset/scene/scene_nor/l7/l7_scene_01.tif
# 4
# data/dset/scene/scene_nor/l7/l7_scene_06.tif
# 4
# data/dset/scene/scene_nor/l7/l7_scene_11.tif
# 4
# data/dset/scene/scene_nor/l7/l7_scene_16.tif
# 4
# data/dset/scene/scene_nor/l7/l7_scene_21.tif
# 4
# data/dset/scene/scene_nor/l7/l7_scene_26.tif
# 4
# data/dset/scene/scene_nor/l8/l8_scene_01.tif
# 9
# data/dset/scene/scene_nor/l8/l8_scene_06.tif
# 6
# data/dset/scene/scene_nor/l8/l8_scene_11.tif
# 6
# data/dset/scene/scene_nor/l8/l8_scene_16.tif
# 6
# data/dset/scene/scene_nor/l8/l8_scene_21.tif
# 4
# data/dset/scene/scene_nor/l8/l8_scene_26.tif
# 4
# data/dset/scene/scene_nor/l9/l9_scene_01.tif
# 9
# data/dset/scene/scene_nor/l9/l9_scene_06.tif
# 12
# data/dset/scene/scene_nor/l9/l9_scene_11.tif
# 9
# data/dset/scene/scene_nor/l9/l9_scene_16.tif
# 12
# data/dset/scene/scene_nor/l9/l9_scene_21.tif
# 9
# data/dset/scene/scene_nor/l9/l9_scene_26.tif
# 16
# data/dset/scene/scene_nor/s2/S2A_L2A_20190125_N0211_R034_6Bands_S1.tif
# 1
# data/dset/scene/scene_nor/s2/S2A_L2A_20190206_N0211_R067_6Bands_S3.tif
# 4
# data/dset/scene/scene_nor/s2/S2A_L2A_20190318_N0211_R061_6Bands_S2.tif
# 1
# data/dset/scene/scene_nor/s2/S2A_L2A_20190429_N0211_R096_6Bands_S1.tif
# 4
# data/dset/scene/scene_nor/s2/S2A_L2A_20190508_N0212_R078_6Bands_S3.tif
# 1
# data/dset/scene/scene_nor/s2/S2A_L2A_20190716_N0213_R063_6Bands_S2.tif
# 4
# data/dset/scene/scene_nor/s2/S2A_L2A_20190725_N0213_R054_6Bands_S1.tif
# 1
# data/dset/scene/scene_nor/s2/S2A_L2A_20190811_N0213_R013_6Bands_S2.tif
# 6
# data/dset/scene/scene_nor/s2/S2A_L2A_20190817_N0213_R089_6Bands_S4.tif
# 1
# data/dset/scene/scene_nor/s2/S2B_L2A_20181226_N0211_R102_6Bands_S2.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190303_N0211_R065_6Bands_S1.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190430_N0211_R035_6Bands_S3.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190607_N0212_R012_6Bands_S2.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R053_6Bands_S1.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190801_N0213_R084_6Bands_S3.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190811_N0213_R079_6Bands_S2.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190831_N0213_R082_6Bands_S1.tif
# 4
# data/dset/scene/scene_nor/s2/S2B_L2A_20190904_N0213_R132_6Bands_S3.tif
# 6
# data/dset/scene/scene_nor/s2/S2B_L2A_20191015_N0213_R007_6Bands_S2.tif
# 4
# num of patches: 217

# %%
'''----  save multiscale patch data  ----'''
dir_valset = f'data/dset/valset/patch_{patch_size}'
for id_patch, patch_ptruth in enumerate(dset_list):
    print(id_patch)
    patch_ptruth_ = torch.from_numpy(patch_ptruth).permute(2,0,1)  ## (C, H, W)
    ## save as float16 to save space
    patch_ptruth_ = patch_ptruth_.to(dtype=torch.float16)
    path_save = dir_valset+f'/patch_ptruth_' + str(id_patch).rjust(4,'0')+'.pth'
    print(path_save)
    torch.save((patch_ptruth_), path_save)
    # break
# Out:
# 0
# data/dset/valset/patch-512/patch_ptruth_0000.pth
# 1
# data/dset/valset/patch-512/patch_ptruth_0001.pth
# 2
# data/dset/valset/patch-512/patch_ptruth_0002.pth
# 3
# data/dset/valset/patch-512/patch_ptruth_0003.pth
# 4
# data/dset/valset/patch-512/patch_ptruth_0004.pth
# 5
# data/dset/valset/patch-512/patch_ptruth_0005.pth
# 6
# data/dset/valset/patch-512/patch_ptruth_0006.pth
# 7
# data/dset/valset/patch-512/patch_ptruth_0007.pth
# 8
# data/dset/valset/patch-512/patch_ptruth_0008.pth
# 9
# data/dset/valset/patch-512/patch_ptruth_0009.pth
# 10
# data/dset/valset/patch-512/patch_ptruth_0010.pth
# 11
# data/dset/valset/patch-512/patch_ptruth_0011.pth
# 12
# data/dset/valset/patch-512/patch_ptruth_0012.pth
# 13
# data/dset/valset/patch-512/patch_ptruth_0013.pth
# 14
# data/dset/valset/patch-512/patch_ptruth_0014.pth
# 15
# data/dset/valset/patch-512/patch_ptruth_0015.pth
# 16
# data/dset/valset/patch-512/patch_ptruth_0016.pth
# 17
# data/dset/valset/patch-512/patch_ptruth_0017.pth
# 18
# data/dset/valset/patch-512/patch_ptruth_0018.pth
# 19
# data/dset/valset/patch-512/patch_ptruth_0019.pth
# 20
# data/dset/valset/patch-512/patch_ptruth_0020.pth
# 21
# data/dset/valset/patch-512/patch_ptruth_0021.pth
# 22
# data/dset/valset/patch-512/patch_ptruth_0022.pth
# 23
# data/dset/valset/patch-512/patch_ptruth_0023.pth
# 24
# data/dset/valset/patch-512/patch_ptruth_0024.pth
# 25
# data/dset/valset/patch-512/patch_ptruth_0025.pth
# 26
# data/dset/valset/patch-512/patch_ptruth_0026.pth
# 27
# data/dset/valset/patch-512/patch_ptruth_0027.pth
# 28
# data/dset/valset/patch-512/patch_ptruth_0028.pth
# 29
# data/dset/valset/patch-512/patch_ptruth_0029.pth
# 30
# data/dset/valset/patch-512/patch_ptruth_0030.pth
# 31
# data/dset/valset/patch-512/patch_ptruth_0031.pth
# 32
# data/dset/valset/patch-512/patch_ptruth_0032.pth
# 33
# data/dset/valset/patch-512/patch_ptruth_0033.pth
# 34
# data/dset/valset/patch-512/patch_ptruth_0034.pth
# 35
# data/dset/valset/patch-512/patch_ptruth_0035.pth
# 36
# data/dset/valset/patch-512/patch_ptruth_0036.pth
# 37
# data/dset/valset/patch-512/patch_ptruth_0037.pth
# 38
# data/dset/valset/patch-512/patch_ptruth_0038.pth
# 39
# data/dset/valset/patch-512/patch_ptruth_0039.pth
# 40
# data/dset/valset/patch-512/patch_ptruth_0040.pth
# 41
# data/dset/valset/patch-512/patch_ptruth_0041.pth
# 42
# data/dset/valset/patch-512/patch_ptruth_0042.pth
# 43
# data/dset/valset/patch-512/patch_ptruth_0043.pth
# 44
# data/dset/valset/patch-512/patch_ptruth_0044.pth
# 45
# data/dset/valset/patch-512/patch_ptruth_0045.pth
# 46
# data/dset/valset/patch-512/patch_ptruth_0046.pth
# 47
# data/dset/valset/patch-512/patch_ptruth_0047.pth
# 48
# data/dset/valset/patch-512/patch_ptruth_0048.pth
# 49
# data/dset/valset/patch-512/patch_ptruth_0049.pth
# 50
# data/dset/valset/patch-512/patch_ptruth_0050.pth
# 51
# data/dset/valset/patch-512/patch_ptruth_0051.pth
# 52
# data/dset/valset/patch-512/patch_ptruth_0052.pth
# 53
# data/dset/valset/patch-512/patch_ptruth_0053.pth
# 54
# data/dset/valset/patch-512/patch_ptruth_0054.pth
# 55
# data/dset/valset/patch-512/patch_ptruth_0055.pth
# 56
# data/dset/valset/patch-512/patch_ptruth_0056.pth
# 57
# data/dset/valset/patch-512/patch_ptruth_0057.pth
# 58
# data/dset/valset/patch-512/patch_ptruth_0058.pth
# 59
# data/dset/valset/patch-512/patch_ptruth_0059.pth
# 60
# data/dset/valset/patch-512/patch_ptruth_0060.pth
# 61
# data/dset/valset/patch-512/patch_ptruth_0061.pth
# 62
# data/dset/valset/patch-512/patch_ptruth_0062.pth
# 63
# data/dset/valset/patch-512/patch_ptruth_0063.pth
# 64
# data/dset/valset/patch-512/patch_ptruth_0064.pth
# 65
# data/dset/valset/patch-512/patch_ptruth_0065.pth
# 66
# data/dset/valset/patch-512/patch_ptruth_0066.pth
# 67
# data/dset/valset/patch-512/patch_ptruth_0067.pth
# 68
# data/dset/valset/patch-512/patch_ptruth_0068.pth
# 69
# data/dset/valset/patch-512/patch_ptruth_0069.pth
# 70
# data/dset/valset/patch-512/patch_ptruth_0070.pth
# 71
# data/dset/valset/patch-512/patch_ptruth_0071.pth
# 72
# data/dset/valset/patch-512/patch_ptruth_0072.pth
# 73
# data/dset/valset/patch-512/patch_ptruth_0073.pth
# 74
# data/dset/valset/patch-512/patch_ptruth_0074.pth
# 75
# data/dset/valset/patch-512/patch_ptruth_0075.pth
# 76
# data/dset/valset/patch-512/patch_ptruth_0076.pth
# 77
# data/dset/valset/patch-512/patch_ptruth_0077.pth
# 78
# data/dset/valset/patch-512/patch_ptruth_0078.pth
# 79
# data/dset/valset/patch-512/patch_ptruth_0079.pth
# 80
# data/dset/valset/patch-512/patch_ptruth_0080.pth
# 81
# data/dset/valset/patch-512/patch_ptruth_0081.pth
# 82
# data/dset/valset/patch-512/patch_ptruth_0082.pth
# 83
# data/dset/valset/patch-512/patch_ptruth_0083.pth
# 84
# data/dset/valset/patch-512/patch_ptruth_0084.pth
# 85
# data/dset/valset/patch-512/patch_ptruth_0085.pth
# 86
# data/dset/valset/patch-512/patch_ptruth_0086.pth
# 87
# data/dset/valset/patch-512/patch_ptruth_0087.pth
# 88
# data/dset/valset/patch-512/patch_ptruth_0088.pth
# 89
# data/dset/valset/patch-512/patch_ptruth_0089.pth
# 90
# data/dset/valset/patch-512/patch_ptruth_0090.pth
# 91
# data/dset/valset/patch-512/patch_ptruth_0091.pth
# 92
# data/dset/valset/patch-512/patch_ptruth_0092.pth
# 93
# data/dset/valset/patch-512/patch_ptruth_0093.pth
# 94
# data/dset/valset/patch-512/patch_ptruth_0094.pth
# 95
# data/dset/valset/patch-512/patch_ptruth_0095.pth
# 96
# data/dset/valset/patch-512/patch_ptruth_0096.pth
# 97
# data/dset/valset/patch-512/patch_ptruth_0097.pth
# 98
# data/dset/valset/patch-512/patch_ptruth_0098.pth
# 99
# data/dset/valset/patch-512/patch_ptruth_0099.pth
# 100
# data/dset/valset/patch-512/patch_ptruth_0100.pth
# 101
# data/dset/valset/patch-512/patch_ptruth_0101.pth
# 102
# data/dset/valset/patch-512/patch_ptruth_0102.pth
# 103
# data/dset/valset/patch-512/patch_ptruth_0103.pth
# 104
# data/dset/valset/patch-512/patch_ptruth_0104.pth
# 105
# data/dset/valset/patch-512/patch_ptruth_0105.pth
# 106
# data/dset/valset/patch-512/patch_ptruth_0106.pth
# 107
# data/dset/valset/patch-512/patch_ptruth_0107.pth
# 108
# data/dset/valset/patch-512/patch_ptruth_0108.pth
# 109
# data/dset/valset/patch-512/patch_ptruth_0109.pth
# 110
# data/dset/valset/patch-512/patch_ptruth_0110.pth
# 111
# data/dset/valset/patch-512/patch_ptruth_0111.pth
# 112
# data/dset/valset/patch-512/patch_ptruth_0112.pth
# 113
# data/dset/valset/patch-512/patch_ptruth_0113.pth
# 114
# data/dset/valset/patch-512/patch_ptruth_0114.pth
# 115
# data/dset/valset/patch-512/patch_ptruth_0115.pth
# 116
# data/dset/valset/patch-512/patch_ptruth_0116.pth
# 117
# data/dset/valset/patch-512/patch_ptruth_0117.pth
# 118
# data/dset/valset/patch-512/patch_ptruth_0118.pth
# 119
# data/dset/valset/patch-512/patch_ptruth_0119.pth
# 120
# data/dset/valset/patch-512/patch_ptruth_0120.pth
# 121
# data/dset/valset/patch-512/patch_ptruth_0121.pth
# 122
# data/dset/valset/patch-512/patch_ptruth_0122.pth
# 123
# data/dset/valset/patch-512/patch_ptruth_0123.pth
# 124
# data/dset/valset/patch-512/patch_ptruth_0124.pth
# 125
# data/dset/valset/patch-512/patch_ptruth_0125.pth
# 126
# data/dset/valset/patch-512/patch_ptruth_0126.pth
# 127
# data/dset/valset/patch-512/patch_ptruth_0127.pth
# 128
# data/dset/valset/patch-512/patch_ptruth_0128.pth
# 129
# data/dset/valset/patch-512/patch_ptruth_0129.pth
# 130
# data/dset/valset/patch-512/patch_ptruth_0130.pth
# 131
# data/dset/valset/patch-512/patch_ptruth_0131.pth
# 132
# data/dset/valset/patch-512/patch_ptruth_0132.pth
# 133
# data/dset/valset/patch-512/patch_ptruth_0133.pth
# 134
# data/dset/valset/patch-512/patch_ptruth_0134.pth
# 135
# data/dset/valset/patch-512/patch_ptruth_0135.pth
# 136
# data/dset/valset/patch-512/patch_ptruth_0136.pth
# 137
# data/dset/valset/patch-512/patch_ptruth_0137.pth
# 138
# data/dset/valset/patch-512/patch_ptruth_0138.pth
# 139
# data/dset/valset/patch-512/patch_ptruth_0139.pth
# 140
# data/dset/valset/patch-512/patch_ptruth_0140.pth
# 141
# data/dset/valset/patch-512/patch_ptruth_0141.pth
# 142
# data/dset/valset/patch-512/patch_ptruth_0142.pth
# 143
# data/dset/valset/patch-512/patch_ptruth_0143.pth
# 144
# data/dset/valset/patch-512/patch_ptruth_0144.pth
# 145
# data/dset/valset/patch-512/patch_ptruth_0145.pth
# 146
# data/dset/valset/patch-512/patch_ptruth_0146.pth
# 147
# data/dset/valset/patch-512/patch_ptruth_0147.pth
# 148
# data/dset/valset/patch-512/patch_ptruth_0148.pth
# 149
# data/dset/valset/patch-512/patch_ptruth_0149.pth
# 150
# data/dset/valset/patch-512/patch_ptruth_0150.pth
# 151
# data/dset/valset/patch-512/patch_ptruth_0151.pth
# 152
# data/dset/valset/patch-512/patch_ptruth_0152.pth
# 153
# data/dset/valset/patch-512/patch_ptruth_0153.pth
# 154
# data/dset/valset/patch-512/patch_ptruth_0154.pth
# 155
# data/dset/valset/patch-512/patch_ptruth_0155.pth
# 156
# data/dset/valset/patch-512/patch_ptruth_0156.pth
# 157
# data/dset/valset/patch-512/patch_ptruth_0157.pth
# 158
# data/dset/valset/patch-512/patch_ptruth_0158.pth
# 159
# data/dset/valset/patch-512/patch_ptruth_0159.pth
# 160
# data/dset/valset/patch-512/patch_ptruth_0160.pth
# 161
# data/dset/valset/patch-512/patch_ptruth_0161.pth
# 162
# data/dset/valset/patch-512/patch_ptruth_0162.pth
# 163
# data/dset/valset/patch-512/patch_ptruth_0163.pth
# 164
# data/dset/valset/patch-512/patch_ptruth_0164.pth
# 165
# data/dset/valset/patch-512/patch_ptruth_0165.pth
# 166
# data/dset/valset/patch-512/patch_ptruth_0166.pth
# 167
# data/dset/valset/patch-512/patch_ptruth_0167.pth
# 168
# data/dset/valset/patch-512/patch_ptruth_0168.pth
# 169
# data/dset/valset/patch-512/patch_ptruth_0169.pth
# 170
# data/dset/valset/patch-512/patch_ptruth_0170.pth
# 171
# data/dset/valset/patch-512/patch_ptruth_0171.pth
# 172
# data/dset/valset/patch-512/patch_ptruth_0172.pth
# 173
# data/dset/valset/patch-512/patch_ptruth_0173.pth
# 174
# data/dset/valset/patch-512/patch_ptruth_0174.pth
# 175
# data/dset/valset/patch-512/patch_ptruth_0175.pth
# 176
# data/dset/valset/patch-512/patch_ptruth_0176.pth
# 177
# data/dset/valset/patch-512/patch_ptruth_0177.pth
# 178
# data/dset/valset/patch-512/patch_ptruth_0178.pth
# 179
# data/dset/valset/patch-512/patch_ptruth_0179.pth
# 180
# data/dset/valset/patch-512/patch_ptruth_0180.pth
# 181
# data/dset/valset/patch-512/patch_ptruth_0181.pth
# 182
# data/dset/valset/patch-512/patch_ptruth_0182.pth
# 183
# data/dset/valset/patch-512/patch_ptruth_0183.pth
# 184
# data/dset/valset/patch-512/patch_ptruth_0184.pth
# 185
# data/dset/valset/patch-512/patch_ptruth_0185.pth
# 186
# data/dset/valset/patch-512/patch_ptruth_0186.pth
# 187
# data/dset/valset/patch-512/patch_ptruth_0187.pth
# 188
# data/dset/valset/patch-512/patch_ptruth_0188.pth
# 189
# data/dset/valset/patch-512/patch_ptruth_0189.pth
# 190
# data/dset/valset/patch-512/patch_ptruth_0190.pth
# 191
# data/dset/valset/patch-512/patch_ptruth_0191.pth
# 192
# data/dset/valset/patch-512/patch_ptruth_0192.pth
# 193
# data/dset/valset/patch-512/patch_ptruth_0193.pth
# 194
# data/dset/valset/patch-512/patch_ptruth_0194.pth
# 195
# data/dset/valset/patch-512/patch_ptruth_0195.pth
# 196
# data/dset/valset/patch-512/patch_ptruth_0196.pth
# 197
# data/dset/valset/patch-512/patch_ptruth_0197.pth
# 198
# data/dset/valset/patch-512/patch_ptruth_0198.pth
# 199
# data/dset/valset/patch-512/patch_ptruth_0199.pth
# 200
# data/dset/valset/patch-512/patch_ptruth_0200.pth
# 201
# data/dset/valset/patch-512/patch_ptruth_0201.pth
# 202
# data/dset/valset/patch-512/patch_ptruth_0202.pth
# 203
# data/dset/valset/patch-512/patch_ptruth_0203.pth
# 204
# data/dset/valset/patch-512/patch_ptruth_0204.pth
# 205
# data/dset/valset/patch-512/patch_ptruth_0205.pth
# 206
# data/dset/valset/patch-512/patch_ptruth_0206.pth
# 207
# data/dset/valset/patch-512/patch_ptruth_0207.pth
# 208
# data/dset/valset/patch-512/patch_ptruth_0208.pth
# 209
# data/dset/valset/patch-512/patch_ptruth_0209.pth
# 210
# data/dset/valset/patch-512/patch_ptruth_0210.pth
# 211
# data/dset/valset/patch-512/patch_ptruth_0211.pth
# 212
# data/dset/valset/patch-512/patch_ptruth_0212.pth
# 213
# data/dset/valset/patch-512/patch_ptruth_0213.pth
# 214
# data/dset/valset/patch-512/patch_ptruth_0214.pth
# 215
# data/dset/valset/patch-512/patch_ptruth_0215.pth
# 216
# data/dset/valset/patch-512/patch_ptruth_0216.pth

# %% [markdown]
# ### load data and check

# %%
## load data
paths_valset = sorted(glob('data/dset/valset/patch_512/*'))
valset_list = [torch.load(path, weights_only=False) for path in paths_valset]
print(len(valset_list))
# Out:
# 217

# %%
id = np.random.randint(0, len(valset_list))
patch_ptruth = valset_list[id]
patch, ptruth = patch_ptruth[0:6, :, :], patch_ptruth[6:7, :, :]
imgs_name = ['patch', 'ptruth']  
clip_list = [2, 0]  
col_bands_list = [(3,2,1), (0,0,0)]
imsShow(img_list=[patch.numpy().transpose(1,2,0), 
                  ptruth.numpy().transpose(1,2,0)], 
            img_name_list=imgs_name,
            clip_list=clip_list, 
            color_bands_list=col_bands_list,
            figsize=(7, 3));
